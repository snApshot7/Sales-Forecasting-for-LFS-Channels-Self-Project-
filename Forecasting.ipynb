# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install openpyxl

# %%
df_23_24_sales = pd.read_excel('SECONDARY YTD 23-24 Fragrance - Till February.xlsx', sheet_name="BASE DATA")

# %%
df_23_24_sales.head()
# Out:
#       Year      Month Month Key QTR Region         Invoice Date   Material  \
# 0  2023-24 2023-04-01       Apr  Q1  SOUTH  2023-04-25 00:00:00  NFFW02PFL
# 1  2023-24 2023-04-01       Apr  Q1  SOUTH  2023-04-25 00:00:00  NGFM08PC1
# 2  2023-24 2023-04-01       Apr  Q1  SOUTH  2023-04-30 00:00:00  NEFW14PH1
# 3  2023-24 2023-04-01       Apr  Q1  SOUTH  2023-04-14 00:00:00  NEFW12PD1
# 4  2023-24 2023-04-01       Apr  Q1  SOUTH  2023-04-15 00:00:00  NEFW12PD1
#
#    Quantity Gender Brand  ...   Bill to Party Name   MRP Gross UCP  Net UCP  \
# 0       1.0      L    TF  ...     SRI SAI AGENCIES  1895    1895.0   1895.0
# 1       1.0      G    TF  ...  SHRI RADHE AGENCIES  2695    2695.0   2695.0
# 2       1.0      L    TF  ...  SHRI RADHE AGENCIES  1345    1345.0   1345.0
# 3       1.0      L    TF  ...   BRIHAT ENTERPRISES   645     645.0    580.0
# 4       1.0      L    TF  ...   BRIHAT ENTERPRISES   645     645.0    580.0
#
# ...

# %%
#To get the data of the LFS from the Channel-2 column from the data with all the columns
df_23_24_sales_lfs = df_23_24_sales[df_23_24_sales['Channel-2'] == 'LFS']

# %%
df_23_24_sales_lfs.head()
# Out:
#           Year      Month Month Key QTR Region         Invoice Date  \
# 42915  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-20 00:00:00
# 42916  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-21 00:00:00
# 42917  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-20 00:00:00
# 42918  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-27 00:00:00
# 42919  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-22 00:00:00
#
#         Material  Quantity Gender Brand  ... Bill to Party Name   MRP  \
# 42915  NFFW14PH1       2.0      L    TF  ...  158-SSL-VIJAYWADA  1595
# 42916  NEFM14PK1       1.0      G    TF  ...  158-SSL-VIJAYWADA  2495
# 42917    FM20PC1       1.0      L    TF  ...  158-SSL-VIJAYWADA  1595
# 42918    FM20PC1       1.0      L    TF  ...  158-SSL-VIJAYWADA  1595
# 42919  NEFM02PFC       1.0      G    TF  ...  158-SSL-VIJAYWADA  2295
#
#       Gross UCP  Net UCP  Bill to Party City  ShiptopartyStateCode  Channel-2  \
# ...

# %%
df_23_24_sales_lfs.shape
# Out:
# (182374, 23)

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached multimethod-1.11.2-py3-none-any.whl.metadata (9.1 kB)
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# ...
#    ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#    ----------------------------- ---------- 194.6/262.6 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 262.6/262.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.7 MB 16.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.7/4.7 MB 8.9 MB/s eta 0:00:01
#    ------- -------------------------------- 0.9/4.7 MB 6.9 MB/s eta 0:00:01
#    ------- -------------------------------- 0.9/4.7 MB 6.9 MB/s eta 0:00:01
#    ------- -------------------------------- 0.9/4.7 MB 6.9 MB/s eta 0:00:01
# ...

# %%
pip install ydata-profiling
# Out:
# ...
#   Using cached ydata_profiling-4.8.3-py2.py3-none-any.whl.metadata (20 kB)
# ...
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/107.3 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/107.3 kB 640.0 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/107.3 kB 980.4 kB/s eta 0:00:01
#      ------------------------------------ 107.3/107.3 kB 882.6 kB/s eta 0:00:00
# ...
#   Using cached visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached typeguard-4.2.1-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached ydata_profiling-4.8.3-py2.py3-none-any.whl (359 kB)
# Using cached dacite-1.8.1-py3-none-any.whl (14 kB)
# ...

# %%
# from pydantic_settings import BaseSettings
from ydata_profiling import ProfileReport
df_23_24_sales_lfs_profile = ProfileReport(df_23_24_sales_lfs)
df_23_24_sales_lfs_profile.to_file(output_file="df_23_24_sales_lfs_profile.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_23_24_sales_lfs['Gender'].value_counts()
# Out:
# Gender
# G    102230
# L     71630
# P      8174
# U       340
# Name: count, dtype: int64

# %%
df_23_24_sales_lfs['Brand'].value_counts()
# Out:
# Brand
# TF    179509
# Tf      2520
# FP       345
# Name: count, dtype: int64

# %%
demo_brand_check = df_23_24_sales_lfs[df_23_24_sales_lfs['Brand'] == 'Tf']

# %%
demo_brand_check.head()
# Out:
#           Year      Month Month Key QTR Region         Invoice Date  \
# 50371  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-03 00:00:00
# 50379  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-24 00:00:00
# 50423  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-09 00:00:00
# 50514  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-08 00:00:00
# 50517  2023-24 2023-04-01       Apr  Q1  NORTH  2023-04-09 00:00:00
#
#         Material  Quantity Gender Brand  ...               Bill to Party Name  \
# 50371  NFFW02PFC       1.0      L    Tf  ...    LS-Metro Junction Mall-Kalyan
# 50379  NFFW02PFC       1.0      L    Tf  ...  Forum Esplanade-Bhubaneshwar-Ls
# 50423  NFFW02PFC       3.0      L    Tf  ...    Sarath City Mall-Hyderabad-LS
# 50514  NFFW02PFC       1.0      L    Tf  ...         Ahmedabad-Alpha One Mall
# 50517  NFFW02PFC       1.0      L    Tf  ...                   Quest Kolkatta
#
#         MRP Gross UCP  Net UCP  Bill to Party City  ShiptopartyStateCode  \
# ...

# %%
df_23_24_sales_lfs['Brand'] = df_23_24_sales_lfs['Brand'].replace('Tf', 'TF')

# %%
df_23_24_sales_lfs['Billing grp'].nunique()
# Out:
# 1

# %%
df_23_24_sales_lfs['ShiptopartyStateCode'].value_counts()
# Out:
# ShiptopartyStateCode
# MAHARASTRA           39645
# KARNATAKA            22044
# WEST BENGAL          19783
# DELHI                12535
# UTTAR PRADESH        11321
# WESTBENGAL            8276
# GUJARAT               8062
# Telangana             7312
# HARYANA               6206
# TAMIL NADU            5530
# UTTARPRADESH          4556
# MADHYA PRADESH        4070
# ORISSA                3303
# ANDHRA PRADESH        3160
# RAJASTHAN             2974
# TELANGANA             2574
# BIHAR                 2560
# TAMILNADU             2319
# PUNJAB                2223
# ASSAM                 2170
# Kerala                2157
# MADHYAPRADESH         1611
# JHARKHAND             1590
# CHATTISGARH           1588
# Mumbai                1095
# Goa                   1068
# KERALA                 847
# UTTARAKHAND            613
# GOA                    392
# JAMMU & KASHMIR        293
# Meghalaya              256
# MEGHALAYA              120
# Arunachal Pradesh       55
# ...

# %%
df_23_24_sales_lfs['ShiptopartyStateCode'].value_counts(1)
# Out:
# ShiptopartyStateCode
# MAHARASTRA           0.217383
# KARNATAKA            0.120872
# WEST BENGAL          0.108475
# DELHI                0.068732
# UTTAR PRADESH        0.062076
# WESTBENGAL           0.045379
# GUJARAT              0.044206
# Telangana            0.040093
# HARYANA              0.034029
# TAMIL NADU           0.030322
# UTTARPRADESH         0.024982
# MADHYA PRADESH       0.022317
# ORISSA               0.018111
# ANDHRA PRADESH       0.017327
# RAJASTHAN            0.016307
# TELANGANA            0.014114
# BIHAR                0.014037
# TAMILNADU            0.012716
# PUNJAB               0.012189
# ASSAM                0.011899
# Kerala               0.011827
# MADHYAPRADESH        0.008833
# JHARKHAND            0.008718
# CHATTISGARH          0.008707
# Mumbai               0.006004
# Goa                  0.005856
# KERALA               0.004644
# UTTARAKHAND          0.003361
# GOA                  0.002149
# JAMMU & KASHMIR      0.001607
# ...

# %%
df_23_24_sales_lfs['Bill to Party City'].value_counts() #Location where billed party is located
# Out:
# Bill to Party City
# Kolkata      20722
# Mumbai       20155
# Bangalore    19210
# Pune         12133
# Delhi        10495
#              ...
# Hadapsard        5
# ITANAGAR         4
# Kompally         4
# Rajkot           4
# DIMAPUR          3
# Name: count, Length: 139, dtype: int64

# %%
# df_23_24_sales_lfs[' Net UCP'] = df_23_24_sales_lfs[' Net UCP'].replace('Net UCP', 'Net UCP', regex=True)

mean_value = df_23_24_sales_lfs[' Net UCP'].mean()
median_value = df_23_24_sales_lfs[' Net UCP'].median()
print(mean_value, median_value)
# Out:
# 1805.9932097777094 1795.5

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_23_24_sales_lfs is already defined

# Step 1: Strip extra spaces from column names
df_23_24_sales_lfs.columns = df_23_24_sales_lfs.columns.str.strip()

# Step 2: Verify the data type of 'Net UCP'
print(df_23_24_sales_lfs['Net UCP'].dtype)  # Should output float64
print(df_23_24_sales_lfs['Net UCP'].head())

# Step 3: Plot histogram using the corrected column name
sns.histplot(data=df_23_24_sales_lfs, x='Net UCP', bins=1)
# Out:
# float64
# 42915    3190.0
# 42916    1995.0
# 42917    1595.0
# 42918    1595.0
# 42919    2295.0
# Name: Net UCP, dtype: float64
# <Axes: xlabel='Net UCP', ylabel='Count'>

# %%
df_23_24_sales_lfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182374 entries, 42915 to 940531
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Year                  182374 non-null  object
#  1   Month                 182374 non-null  datetime64[ns]
#  2   Month Key             182374 non-null  object
#  3   QTR                   182374 non-null  object
#  4   Region                168017 non-null  object
#  5   Invoice Date          182374 non-null  object
#  6   Material              182374 non-null  object
#  7   Quantity              182374 non-null  float64
#  8   Gender                182374 non-null  object
#  9   Brand                 182374 non-null  object
#  10  Channel               182374 non-null  object
#  11  Franchisee store      164255 non-null  object
#  12  Bill to Party code    182374 non-null  object
#  13  Bill to Party Name    182374 non-null  object
# ...

# %%
#Plot graph between Net UCP and Quantity
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_23_24_sales_lfs, x='Net UCP', y='Quantity')
# Out:
# <Axes: xlabel='Net UCP', ylabel='Quantity'>

# %%
# !pip install matplotlib --upgrade
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.0 MB 1.1 MB/s eta 0:00:08
#    --- ------------------------------------ 0.6/8.0 MB 6.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/8.0 MB 5.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.0 MB 5.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.0 MB 5.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.0 MB 5.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.0 MB 3.3 MB/s eta 0:00:03
#    -------- ------------------------------- 1.7/8.0 MB 4.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.0 MB 4.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.0 MB 4.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.0 MB 4.4 MB/s eta 0:00:02
# ...
